# %% [markdown]
# # Demo basico de funciones
# Ejemplos con distintas combinaciones de entradas y salidas.

# %%
from functions import in0_out1, in0_out2, in2_out2

in0_out1()
in0_out2()
in2_out2("a", "b")
